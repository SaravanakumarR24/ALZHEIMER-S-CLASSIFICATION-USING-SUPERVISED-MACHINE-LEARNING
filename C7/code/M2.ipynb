# %%
import pandas as pd 
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_csv('A.csv')
d.head()
# Out:
#          Group M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1  Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2     Demented   M   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3     Demented   M   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4     Demented   M   80    12  NaN  22.0  0.5  1698  0.701  1.034

# %%
d.columns
# Out:
# Index(['Group', 'M/F', 'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV',
#        'ASF'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(d['Group'],color='red')

plt.subplot(1,2,2)
plt.hist(d['Age'],color='blue')
# Out:
# (array([13., 25., 57., 71., 53., 66., 44., 28., 12.,  4.]),
#  array([60. , 63.8, 67.6, 71.4, 75.2, 79. , 82.8, 86.6, 90.4, 94.2, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
d.hist(figsize=(15,55),layout=(15,4), color='red')
plt.show()

# %%
d['EDUC'].hist(figsize=(10,5),color='red')
# Out:
# <AxesSubplot:>

# %%
plt.bar(d['CDR'],d['eTIV'], color='red') # scatter, plot, triplot, stackplot
# Out:
# <BarContainer object of 373 artists>

# %%
plt.boxplot(d['nWBV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2531947c0a0>,
#   <matplotlib.lines.Line2D at 0x2531950b0d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2531950ba00>,
#   <matplotlib.lines.Line2D at 0x2531950b820>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2531947cd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2531950bf40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2531950b550>],
#  'means': []}

# %%
d['ASF'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(d['Group'], color='red') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.residplot(d['SES'],d['MMSE'], color='red') # residplot, scatterplot
# Out:
# C:\Users\SPIRO15\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SES', ylabel='MMSE'>

# %%
sns.pairplot(d)

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(d.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <AxesSubplot:>

# %%
def plot(d, variable):
    dataframe_pie = d[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return n.round(dataframe_pie/d.shape[0]*100,2)

plot(d, 'Group')
# Out:
# Nondemented    50.94
# Demented       39.14
# Converted       9.92
# Name: Group, dtype: float64
